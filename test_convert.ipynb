# %%
from simbanator.data.convert import convert_hdf5_fits
from simbanator.io.simba import Simulation
sim = Simulation("pc39")

# %%
convert_hdf5_fits(sim, range(130, 149, 1), verbose=2)
# Out:
# Processing: /media/lorenzong/Data1/SIMBA_catalogs/m100n1024_130.hdf5
# Processing /media/lorenzong/Data1/SIMBA_catalogs/m100n1024_130.hdf5
#   n_galaxies=46934, n_halos=493746
#   Skipping galaxy_data/lists/bhlist: rows 20001 != n_galaxies 46934
#   Skipping galaxy_data/lists/cloud_index_list: rows 0 != n_galaxies 46934
#   Skipping galaxy_data/lists/glist: rows 9350094 != n_galaxies 46934
#   Skipping galaxy_data/lists/slist: rows 35226491 != n_galaxies 46934
#   Skipping global_lists/galaxy_bhlist: rows 38579 != n_galaxies 46934
#   Skipping global_lists/galaxy_glist: rows 1023930978 != n_galaxies 46934
#   Skipping global_lists/galaxy_slist: rows 50046439 != n_galaxies 46934
#   Skipping global_lists/halo_bhlist: rows 38579 != n_galaxies 46934
#   Skipping global_lists/halo_dmlist: rows 1073741824 != n_galaxies 46934
#   Skipping global_lists/halo_glist: rows 1023930978 != n_galaxies 46934
#   Skipping global_lists/halo_slist: rows 50046439 != n_galaxies 46934
# ...
