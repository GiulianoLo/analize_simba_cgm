# %%
cs = sb.get_caesar(129)
pos = [i.pos.in_units('code_length') for i in cs.galaxies]
import time
start = time.time()
filter_by_aperture(cs=cs,\
                        simfile=sb.get_sim_file(129),\
                        snap=129, 
                        center= pos[0].value,\
                        radius=100,\
                        selection='galaxy',\
                        verbose=1, overwrite=True, ignore_fields=[], keyword=None, closegal=0)
end = time.time()
print(end-start)
