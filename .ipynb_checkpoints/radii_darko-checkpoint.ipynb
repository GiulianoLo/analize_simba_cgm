# %%
import os
import yt, caesar
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import modules as anal
import modules.anal_func as anal_func

from astropy.cosmology import LambdaCDM
import astropy.units as u
from astropy.io import fits
from scipy import interpolate

# %%
cosmo = LambdaCDM(H0 = 68, Om0= 0.3, Ode0= 0.7, Ob0=0.048)

plt.rcParams.update({
 "savefig.facecolor": "w",
 "figure.facecolor" : 'w',
 "figure.figsize" : (10,8),
 "text.color": "k",
 "legend.fontsize" : 20,
 "font.size" : 30,
 "axes.edgecolor": "k",
 "axes.labelcolor": "k",
 "axes.linewidth": 3,
 "xtick.color": "k",
 "ytick.color": "k",
 "xtick.labelsize" : 25,
 "ytick.labelsize" : 25,
 "ytick.major.size" : 12,
 "xtick.major.size" : 12,
 "ytick.major.width" : 2,
 "xtick.major.width" : 2,
 "font.family": 'STIXGeneral',
 "mathtext.fontset" : "cm"})

snap = 129
n = 0

# decide the snapshot
sb = anal.Simba('PC39BP4', size=100)
snapfile = sb.get_sim_file(snap)
catfile  = sb.get_caesar_file(snap)


# initialize the SavePaths class to create destinations
sv = anal.SavePaths() 
pltsv  = sv.get_filetype_path('plot')
scatter = sv.create_subdir(pltsv, 'scatter')

# %%
# I will work with a single snapshot for now
snap = 129
cs = sb.get_caesar(snap)
a = cs.simulation.scale_factor
z = sb.get_redshifts()
clust_mass_thresh = 1e14
# Out:
# yt : [INFO     ] 2024-09-13 15:02:35,774 Opening /media/lorenzong/Data1/SIMBA_catalogs/m100n1024_129.hdf5
# yt : [INFO     ] 2024-09-13 15:02:36,046 Found 495012 halos
# yt : [INFO     ] 2024-09-13 15:02:36,867 Found 46575 galaxies

# %%
id  = np.asarray([i.GroupID for i in cs.galaxies])
sfr = np.asarray([i.sfr for i in cs.galaxies])
m   = np.asarray([i.masses['stellar'] for i in cs.galaxies])
m_g = np.asarray([i.masses['H2'] for i in cs.galaxies])
m_d = np.asarray([i.masses['dust'] for i in cs.galaxies])
r_star  = np.asarray([i.radii['stellar_r80'] for i in cs.galaxies])
r_gas   = np.asarray([i.radii['gas_r80'] for i in cs.galaxies])
T_cgm   = np.asarray([i.temperatures['mass_weighted_cgm'] for i in cs.galaxies])

mass_cut = m > 1e9
qg = np.all([sfr/m < 0.2/cosmo.age(sb.get_z_from_snap(snap)).to(u.yr).value, m > 1e10], axis=0)
sf = np.all([sfr/m > 1./cosmo.age(sb.get_z_from_snap(snap)).to(u.yr).value, m>1e10], axis=0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))

ax.scatter(r_star[qg], r_gas[qg], c=np.log10((m_d/m_g))[qg], alpha=0.1, cmap='inferno')
ax.scatter(r_star[sf], r_gas[sf], c=np.log10((m_d/m_g))[sf], alpha=0.1)
# Out:
# /tmp/ipykernel_152917/596833094.py:3: RuntimeWarning: divide by zero encountered in divide
#   ax.scatter(r_star[qg], r_gas[qg], c=np.log10((m_d/m_g))[qg], alpha=0.1, cmap='inferno')
# /tmp/ipykernel_152917/596833094.py:3: RuntimeWarning: invalid value encountered in divide
#   ax.scatter(r_star[qg], r_gas[qg], c=np.log10((m_d/m_g))[qg], alpha=0.1, cmap='inferno')
# /tmp/ipykernel_152917/596833094.py:3: RuntimeWarning: divide by zero encountered in log10
#   ax.scatter(r_star[qg], r_gas[qg], c=np.log10((m_d/m_g))[qg], alpha=0.1, cmap='inferno')
# /tmp/ipykernel_152917/596833094.py:4: RuntimeWarning: divide by zero encountered in divide
#   ax.scatter(r_star[sf], r_gas[sf], c=np.log10((m_d/m_g))[sf], alpha=0.1)
# /tmp/ipykernel_152917/596833094.py:4: RuntimeWarning: invalid value encountered in divide
#   ax.scatter(r_star[sf], r_gas[sf], c=np.log10((m_d/m_g))[sf], alpha=0.1)
# /tmp/ipykernel_152917/596833094.py:4: RuntimeWarning: divide by zero encountered in log10
#   ax.scatter(r_star[sf], r_gas[sf], c=np.log10((m_d/m_g))[sf], alpha=0.1)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
ax.scatter(np.log10((m_d/m))[qg], r_gas[qg], c=np.log10(T_cgm)[qg], alpha=0.1, cmap='inferno')
ax.scatter(np.log10((m_d/m))[sf], r_gas[sf], c=np.log10((T_cgm))[sf], alpha=0.1)
# Out:
# /tmp/ipykernel_152917/1494389980.py:2: RuntimeWarning: divide by zero encountered in log10
#   ax.scatter(np.log10((m_d/m))[qg], r_gas[qg], c=np.log10(T_cgm)[qg], alpha=0.1, cmap='inferno')
# /tmp/ipykernel_152917/1494389980.py:3: RuntimeWarning: divide by zero encountered in log10
#   ax.scatter(np.log10((m_d/m))[sf], r_gas[sf], c=np.log10((T_cgm))[sf], alpha=0.1)

# %%
# Enable interactive plotting in Jupyter Lab
# %matplotlib widget


# Create 3D figure and axis
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with three dimensions (T_cgm, r_gas, m_d/m)
sc = ax.scatter(np.log10(m)[qg],  # X-axis (log10(T_cgm))
                r_gas[qg],            # Y-axis (r_gas)
                np.log10((m_d/m))[qg], # Z-axis (log10(m_d/m))
                c=np.log10((m_d/m))[qg], # Color by log10(m_d/m)
                alpha=0.1, cmap='inferno')

# Add colorbar for the scatter plot
cb = fig.colorbar(sc, ax=ax, shrink=0.6)
cb.set_label('log10(m_d/m)')

# Set axis labels
ax.set_xlabel('log10(T_cgm)')
ax.set_ylabel('r_gas')
ax.set_zlabel('log10(m_d/m)')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_4089723/1012978750.py:12: RuntimeWarning: divide by zero encountered in log10
#   np.log10((m_d/m))[qg], # Z-axis (log10(m_d/m))
# /tmp/ipykernel_4089723/1012978750.py:13: RuntimeWarning: divide by zero encountered in log10
#   c=np.log10((m_d/m))[qg], # Color by log10(m_d/m)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sb = anal.Simba('PC39BP4', size=25) #always keep track of the size of the simulation!!!!!!
z = sb.get_redshifts()
cs = sb.get_caesar(44)

snap = 44
n = 0

snapfile = sb.get_sim_file(snap)
catfile  = sb.get_caesar(snap)
# Out:
# yt : [INFO     ] 2024-09-13 16:05:29,230 Opening /media/lorenzong/Data1/simba_hig_res/m25n512_044.hdf5
# yt : [INFO     ] 2024-09-13 16:05:29,294 Found 171287 halos
# yt : [INFO     ] 2024-09-13 16:05:29,296 Found 1773 galaxies
# yt : [INFO     ] 2024-09-13 16:05:29,297 Opening /media/lorenzong/Data1/simba_hig_res/m25n512_044.hdf5
# yt : [INFO     ] 2024-09-13 16:05:29,301 Found 171287 halos
# yt : [INFO     ] 2024-09-13 16:05:29,303 Found 1773 galaxies

# %%
ds = yt.load(snapfile)
ad = ds.all_data()
# Out:
# yt : [INFO     ] 2024-09-13 16:05:29,950 Calculating time from 1.736e-01 to be 3.986e+16 seconds
# yt : [INFO     ] 2024-09-13 16:05:29,951 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2024-09-13 16:05:29,992 Parameters: current_time              = 3.9858341761438936e+16 s
# yt : [INFO     ] 2024-09-13 16:05:29,992 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-09-13 16:05:29,993 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-09-13 16:05:29,994 Parameters: domain_right_edge         = [25000. 25000. 25000.]
# yt : [INFO     ] 2024-09-13 16:05:29,994 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2024-09-13 16:05:29,994 Parameters: current_redshift          = 4.761397524829645
# yt : [INFO     ] 2024-09-13 16:05:29,994 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2024-09-13 16:05:29,995 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2024-09-13 16:05:29,995 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2024-09-13 16:05:29,995 Parameters: hubble_constant           = 0.68
# yt : [INFO     ] 2024-09-13 16:05:30,077 Allocating for 2.684e+08 particles
# Loading particle index: 100%|██████████████████████████████████████████████████████████████████| 512/512 [00:00<00:00, 2577.71it/s]

# %%
import yt
import numpy as np
import caesar

def calculate_radial_profiles_dict(snapfile, catfile, galaxy_id, properties_dict, radii=np.arange(0, 100, 1), region=False, dens=False, dim=None):
    """
    Load snapshot data and return radial profiles of specified properties, always loading coordinates.
    
    Parameters:
    - snapfile: path to the simulation snapshot file.
    - catfile: path to the Caesar catalog file.
    - galaxy_id: the index of the galaxy in the Caesar catalog.
    - properties_dict: dictionary where keys are particle types (e.g., 'PartType0') and values are lists of properties (e.g., ['Masses', 'Metallicity']).
    - radii: range of radii for which to compute profiles (default: np.arange(0, 100, 1)).
    - region: Boolean to compute properties for a larger region or just the galaxy itself.
    - dim: dictionary where keys are particle types and values are lists of unit conversions for each property
      (e.g., {'PartType0': {'Masses': ['code_mass', 'Msun'], 'Metallicity': ['dimensionless', 'dimensionless']}}).
    
    Returns:
    - radii: array of radial distances.
    - profiles: dictionary containing radial profiles for each particle type and property.
    """
    ds = yt.load(snapfile)
    obj = caesar.load(catfile)
    ad = ds.all_data()
    gal = obj.galaxies[galaxy_id]
    center = gal.pos.in_units('kpc').value

    def get_data(particle_type, props, dim, indices=None):
        pos = ad[particle_type, 'Coordinates'].in_units('kpc').value
        data_list = []
        for prop in props:
            data = ad[particle_type, prop[:-2] if '_s' in prop else prop]
            if indices is not None:
                pos = pos[indices]
                data = data[indices]
           
            # Convert property data using the dimensional units before and after conversion
            print(dim[particle_type][0], dim[particle_type][1])
            data = ds.arr(data, dim[particle_type][0]).in_units(dim[particle_type][1]).value
            
            data_list.append(data)
    
        return pos, data_list

    # Prepare to store profiles
    profiles = {ptype: {prop: [] for prop in properties_dict[ptype]} for ptype in properties_dict}

    # Load coordinates and relevant properties for each particle type
    if region:
        for ptype, props in properties_dict.items():
            if ptype == 'PartType0':  # Gas particles
                pos, data = get_data(ptype, props, dim, indices=None)
            elif ptype == 'PartType4':  # Star particles
                pos, data = get_data(ptype, props, dim, indices=None)

            # Calculate radial distances from galaxy center
            radial_distances = np.sqrt(np.sum((pos - center) ** 2, axis=1))

            # Calculate radial profiles for the current particle type and properties
            for r in radii:
                mask = radial_distances < r
                A = np.pi * r ** 2
                
                for i, prop in enumerate(props):
                    if dens:
                        profiles[ptype][prop].append(sum(data[i][mask]) / A)  # Surface density
                    else:
                        profiles[ptype][prop].append(np.mean(data[i][mask]))  # Mean property like metallicity
        
    
    else:
        for ptype, props in properties_dict.items():
            if ptype == 'PartType0':  # Gas particles
                pos, data = get_data(ptype, props, dim, indices=gal.glist)
            elif ptype == 'PartType4':  # Star particles
                pos, data = get_data(ptype, props, dim, indices=gal.slist)

            print(ptype, pos)
            print(ptype, data)

            # Calculate radial distances from galaxy center
            radial_distances = np.sqrt(np.sum((pos - center) ** 2, axis=1))
            
            # Calculate radial profiles for the current particle type and properties
            for r in radii:
                mask = radial_distances < r
                A = np.pi * r ** 2
                
                for i, prop in enumerate(props):
                    if dens:
                        profiles[ptype][prop].append(sum(data[i][mask]) / A)  # Surface density
                    else:
                        profiles[ptype][prop].append(np.mean(data[i][mask]))  # Mean property like metallicity
        
    #Normalize the profiles
    for ptype in profiles:
        for prop in profiles[ptype]:
            if len(profiles[ptype][prop]) > 0:
                profiles[ptype][prop] = np.array(profiles[ptype][prop]) / profiles[ptype][prop][-1]

    return radii, profiles

# %%
snapfile = sb.get_sim_file(129)
catfile = sb.get_caesar_file(129)

properties_dict = {
    'PartType0': ['Masses', 'Dust_Masses_s'],            
    'PartType4': ['Masses']
}

dim = {
    'PartType0': ['code_mass', 'Msun'],
    'PartType4': ['code_mass', 'Msun']
}

radii, profiles = calculate_radial_profiles_dict(
    snapfile, catfile, galaxy_id=0,
    properties_dict=properties_dict,
    radii=np.arange(0, 100, 1),
    region=False,
    dim=dim
)
# Out:
# yt : [INFO     ] 2024-09-13 16:40:09,846 Calculating time from 7.114e-01 to be 2.969e+17 seconds
# yt : [INFO     ] 2024-09-13 16:40:09,847 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2024-09-13 16:40:09,867 Parameters: current_time              = 2.968791388457766e+17 s
# yt : [INFO     ] 2024-09-13 16:40:09,867 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-09-13 16:40:09,868 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-09-13 16:40:09,868 Parameters: domain_right_edge         = [25000. 25000. 25000.]
# yt : [INFO     ] 2024-09-13 16:40:09,868 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2024-09-13 16:40:09,868 Parameters: current_redshift          = 0.4057579856290421
# yt : [INFO     ] 2024-09-13 16:40:09,869 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2024-09-13 16:40:09,869 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2024-09-13 16:40:09,869 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2024-09-13 16:40:09,869 Parameters: hubble_constant           = 0.68
# yt : [INFO     ] 2024-09-13 16:40:09,889 Opening /media/lorenzong/Data1/simba_hig_res/m25n512_129.hdf5
# yt : [INFO     ] 2024-09-13 16:40:10,050 Found 263961 halos
# yt : [INFO     ] 2024-09-13 16:40:10,207 Found 5290 galaxies
# yt : [INFO     ] 2024-09-13 16:40:10,373 Allocating for 2.685e+08 particles
# Loading particle index: 100%|██████████████████████████████████████████████████████████████████| 512/512 [00:00<00:00, 1647.40it/s]
# code_mass Msun
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 14
#       4 properties_dict = {
#       5     'PartType0': ['Masses', 'Dust_Masses_s'],
#       6     'PartType4': ['Masses']
#       7 }
#       9 dim = {
#      10     'PartType0': ['code_mass', 'Msun'],
#      11     'PartType4': ['code_mass', 'Msun']
#      12 }
# ---> 14 radii, profiles = calculate_radial_profiles_dict(
#      15     snapfile, catfile, galaxy_id=0,
#      16     properties_dict=properties_dict,
#      17     radii=np.arange(0, 100, 1),
#      18     region=False,
#      19     dim=dim
#      20 )
#
# Cell In[41], line 75, in calculate_radial_profiles_dict(snapfile, catfile, galaxy_id, properties_dict, radii, region, dens, dim)
#      73 for ptype, props in properties_dict.items():
#      74     if ptype == 'PartType0':  # Gas particles
# ---> 75         pos, data = get_data(ptype, props, dim, indices=gal.glist)
#      76     elif ptype == 'PartType4':  # Star particles
#      77         pos, data = get_data(ptype, props, dim, indices=gal.slist)
#
# Cell In[41], line 35, in calculate_radial_profiles_dict.<locals>.get_data(particle_type, props, dim, indices)
#      33 data = ad[particle_type, prop[:-2] if '_s' in prop else prop]
#      34 if indices is not None:
# ---> 35     pos = pos[indices]
#      36     data = data[indices]
#      38 # Convert property data using the dimensional units before and after conversion
#
# IndexError: index 78484573 is out of bounds for axis 0 with size 85524

# %%
print(profiles)
# Out:
# {'PartType0': {'Masses': [nan, 2946561.6196906455, 2959084.475741409, 2948002.4271066827, 2923394.9664397417, 2917035.6145969452, 2908954.2551614135, 2903125.619117532, 2881874.2947906284, 2866792.0544001427, 2853402.5528745614, 2849975.5942906477, 2835750.315723122, 2826401.212514814, 2816007.9157946976, 2804027.874534669, 2792581.748480827, 2779729.9861775646, 2765712.9293090673, 2750027.0823302814, 2738445.890312741, 2730248.8422514787, 2720901.9644629946, 2712742.9724016245, 2703405.5548727475, 2694790.7221199106, 2685970.0306514236, 2675227.572330743, 2664209.6307820207, 2653482.0220770068, 2643569.978838216, 2630252.7392463353, 2609260.3667012, 2589944.74150628, 2572888.525171671, 2559185.9277965142, 2540741.1207370884, 2513066.681562918, 2482292.780262458, 2468579.1954398826, 2454056.0141514633, 2438903.135348338, 2423352.4407402542, 2412744.2954122163, 2403272.1134071536, 2393462.243358922, 2384356.6773786903, 2377617.5155876824, 2372638.8871411853, 2367982.5093606263, 2363938.055754163, 2361410.7788107777, 2358722.5075471397, 2356013.3088167603, 2353322.273491583, 2351042.450625665, 2348776.2173202196, 2347014.251931152, 2345627.251543725, 2343994.2264067954, 2342282.8757666885, 2340326.2737645055, 2338546.830059437, 2336913.437332562, 2335650.6855118917, 2334442.529362445, 2333385.376005544, 2332441.57864349, 2331219.5301913936, 2330475.156620081, 2329721.1748144776, 2329045.4609686304, 2328395.261061022, 2327851.407176847, 2327259.046952248, 2326675.1575776786, 2326088.2008594912, 2325616.3416618505, 2324990.6755535468, 2324395.16026868, 2323875.590075733, 2323280.2620559316, 2322690.387681864, 2322031.652283254, 2321507.498841028, 2320750.9110588795, 2320069.677217396, 2319443.513507279, 2318918.807325465, 2318443.216058359, 2317946.6508192956, 2317480.336646079, 2316987.018398085, 2316581.385584265, 2316197.600356617, 2315870.904973381, 2315475.5
#  5091782.76201162 4078919.386409   4383487.54815867 4271085.13095471
#  5485769.44685705 4365963.19024615 2329933.04106297 2942843.23257778
#  2948413.62012769 3797400.60238606 4309333.55613995 3171113.34879883
#  2660071.27185516 3127917.48643469 3346310.918192   3846494.4843915
#  4854509.50423803 2579004.90610422 2410652.94283223 2488649.06846874
#  2391345.11930923 2782558.16631238 2532556.69068655 2372935.44855407
#  2447210.9918647  2300576.47807852 2693372.25986152 2624573.15864808
#  2643558.70004853 2395527.51094486 2888436.18952395 3455469.11429504
#  3611836.29138395 3610408.49170154 4900287.26156144 3410311.09736137
#  2892459.36608709 3058694.02569335 2500110.84169862 3080258.68006927
#  2836620.88537205 2623820.52503252 2570384.60832144 2630152.53414564
#  2654053.84090948 2393268.96810192 2819593.21856608 4222526.24583266
#  3367189.92056216 2716389.10977772 4966364.0846334  5287176.46375299
#  2714213.81244984 4675321.50009099 2825999.27124786 2501054.79019968
#  2381222.76427663 4034303.21431883 2471794.95465175 2318175.09355845
#  2712571.15801906 2473856.83264035 2917705.44101703 3061963.71264591
#  2840662.25182922 2489547.00723783 2875089.5152745  2362298.42651964
#  2313457.70503942 2356717.33903206 3242256.8063553  2443299.73664956
#  3466765.46648857 2766201.38559819 4594574.2064813  2860292.99947104
#  4405025.66668917 2584626.22535744 2857947.35913548 2862007.3434842
#  2647530.30291211 2635649.73412191 2564789.39691613 3206529.28648462
#  3042433.33041942 2609479.61257497 2412431.9144689  2568751.58383456
#  2464341.16407352 2666293.49960781 2622831.85079201 2312314.95169649
#  2354329.54094208 2356306.67542436 2392801.59482458 2457036.31662764
#  2408826.24947356 2525628.48104657 2561115.68031723 2468055.11243806
#  2492164.63998891 2562246.44972998 2545533.5750902  2372694.48595779
#  2428393.86748314 2323480.12265421 2285805.21412796 2999220.34815502
#  3142486.30756457 2931663.93770234 2642128.97437734 2692984.49412043
#  3046425.90516082 3374962.14128538 3020533.98199325 5480397.65015025
#  2627489.7476576  2490244.00117752 2374839.18146395 2353708.30256108
#  2371990.85805675 2443178.82735392 3871213.48039192 3163999.38824093
#  3396367.36659004 2325373.36962517 2600045.47753316 3202796.93422729
#  2995290.90304585 4302060.59450831]

# %%
gal = cs.galaxies[0]

pgm = ds.arr(ad['PartType0','Masses'][gal.glist], 'code_mass').in_units('Msun').value
psm = ds.arr(ad['PartType4','Masses'][gal.slist], 'code_mass').in_units('Msun').value
pdm = ds.arr(ad['PartType0','Dust_Masses'][gal.glist], 'code_mass').in_units('Msun').value
#pdms = ds.arr(ad['PartType4','Dust_Masses'][gal.slist], 'code_mass').in_units('Msun').value
pgp = ds.arr(ad['PartType0','Coordinates'][gal.glist], 'code_length').in_units('kpc').value
psp = ds.arr(ad['PartType4','Coordinates'][gal.slist], 'code_length').in_units('kpc').value

radii = np.arange(0, 100, 1)
a = cs.simulation.scale_factor

center = np.asarray([i.pos.in_units('kpc').value for i in cs.galaxies if i == gal])

pgr = np.sqrt(np.sum((pgp-center)**2, axis=1))

psr = np.sqrt(np.sum((psp-center)**2, axis=1))

m_gas = []
m_dust = []
#m_dust_s = []
m_stars = []
for r in radii:
    mkg = pgr < r
    mks = psr < r
    A = np.pi*r**2
    m_gas.append(sum(pgm[mkg])/A)
    m_dust.append(sum(pdm[mkg])/A)
    #m_dust_s.append(sum(pdms[mks])/A)
    m_stars.append(sum(psm[mks])/A)

m_gas /= m_gas[-1]
m_dust /= m_dust[-1]
m_stars /= m_stars[-1]
#m_dust_s /= m_dust_s[-1]
# Out:
# /tmp/ipykernel_546768/3879569969.py:27: RuntimeWarning: invalid value encountered in scalar divide
#   m_gas.append(sum(pgm[mkg])/A)
# /tmp/ipykernel_546768/3879569969.py:28: RuntimeWarning: invalid value encountered in scalar divide
#   m_dust.append(sum(pdm[mkg])/A)
# /tmp/ipykernel_546768/3879569969.py:30: RuntimeWarning: invalid value encountered in scalar divide
#   m_stars.append(sum(psm[mks])/A)

# %%
print(pdm)
# Out:
# [3.61062584e+03 1.95157260e+05 1.72746898e+01 ... 2.02355925e+03
#  9.35579457e+02 1.35781340e+05]

# %%
print(pgp, center, pgr)
# Out:
# [[12771.22489234 15893.33031676 19286.94209119]
#  [12770.92045576 15895.01391235 19286.05942942]
#  [12771.39345622 15894.77996612 19285.88780075]
#  ...
#  [12765.63878757 15893.4212391  19290.83234118]
#  [12765.05647599 15892.77558836 19290.56468218]
#  [12765.27816303 15892.88285629 19290.71587887]] [[12774.183 15912.661 19263.816]] [30.28573739 28.58003091 28.54228436 ... 34.24954416 34.55707737
#  34.55504527]

# %%
plt.scatter(pgp[:,0], pgp[:,1], s=0.2)
plt.scatter(psp[:,0], psp[:,1], s=0.1)
#plt.scatter(12774.183, 15912.661, c=r, zorder=10)

# %%
a = np.array([12771.22489234, 15893.33031676, 19286.94209119])
b = np.array([12774.183, 15912.661, 19263.816])
c = a-b
d = np.sqrt(c[0]**2+c[1]**2)
print(d)
# Out:
# 19.55570800184307

# %%
plt.plot(radii, m_gas, label='Gas')
plt.plot(radii, m_dust, label='Dust')
plt.plot(radii, m_stars, label='Stars')
#plt.plot(radii, m_dust_s, label='Dust_s')
plt.yscale('log')
plt.xlim(0,10)
plt.ylabel('Normalized mass surface density')
plt.xlabel('r [Kpc]')
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Define the 1/x^2 function for fitting
def func(x, A):
    return A / x**2

# Subset the data for x > 15
mask = radii > 12
radii_fit = radii[mask]
m_stars_fit = m_stars[mask]

# Perform the curve fitting
popt, pcov = curve_fit(func, radii_fit, m_stars_fit)
A_fit = popt[0]

# Generate the fitted curve using the entire radii array
fitted_stars = func(radii, A_fit)

# Plot the original data and the fitted curve
plt.plot(radii, m_gas, label='Gas')
plt.plot(radii, m_dust, label='Dust')
plt.plot(radii, m_stars, label='Stars')
plt.plot(radii, fitted_stars, 'r--', label=f'1/x^2 (r>)')  # Fitted curve
plt.axvline(10.5, label='r80', color='k', ls=':')
plt.yscale('log')
plt.xlim(0, 30)
plt.ylim(0, 800)
plt.ylabel('Normalized mass surface density')
plt.xlabel('r [Kpc]')
plt.legend()
plt.show()

print([i.radii['stellar_r80'] for i in cs.galaxies][6])
# Out:
# /tmp/ipykernel_546768/18805198.py:7: RuntimeWarning: divide by zero encountered in divide
#   return A / x**2
# /tmp/ipykernel_546768/18805198.py:29: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, 800)
# 5.692184925079346 kpccm
